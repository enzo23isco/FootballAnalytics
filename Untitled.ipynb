# %% [markdown]
# #### Instalar Statsbombpy

# %%
pip install statsbombpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsbombpy import sb

# %% [markdown]
# #### Data de competiciones

# %%
sb.competitions()
# Out:
# credentials were not supplied. open data access only
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# ...

# %% [markdown]
# #### Ver los partidos del World Cup 2018

# %%
df = sb.matches(competition_id=43, season_id=3)
df[df.home_team=="Peru"]
# Out:
# credentials were not supplied. open data access only
#     match_id  match_date      kick_off                     competition season  \
# 37      7532  2018-06-16  18:00:00.000  International - FIFA World Cup   2018
#
#    home_team away_team  home_score  away_score match_status match_status_360  \
# 37      Peru   Denmark           0           1    available        scheduled
#
#         last_updated         last_updated_360  match_week competition_stage  \
# 37  2020-07-29T05:00  2021-06-13T16:17:31.694           1       Group Stage
#
#                      stadium              referee data_version  \
# 37  Mordovia Arena (Saransk)  Bakary Papa Gassama        1.0.2
#
#    shot_fidelity_version xy_fidelity_version
# 37                  None                None

# %% [markdown]
# ### Lineups

# %%
sb.lineups(match_id=7532)["Peru"]
# Out:
# credentials were not supplied. open data access only
#     player_id                               player_name      player_nickname  \
# 0        3632                André Martín Carrillo Díaz       André Carrillo
# 1        5518              Miguel Ángel Trauco Saavedra        Miguel Trauco
# 2        5519             Christian Alberto Cueva Bravo      Christian Cueva
# 3        5521       Luis Jan Piers Advíncula Castrillón       Luis Advíncula
# 4        5523             Renato Fabrizio Tapia Cortijo         Renato Tapia
# 5        5525             Édison Michael Flores Peralta        Edison Flores
# 6        5526                Pedro Jesús Aquino Sánchez         Pedro Aquino
# 7        5528                Pedro David Gallese Quiróz        Pedro Gallese
# 8        5529              Víctor Yoshimar Yotún Flores       Yoshimar Yotún
# 9        5530  Christian Guillermo Martín Ramos Garagay      Christian Ramos
# ...

# %%
events = sb.events(match_id=7532)
# Out:
# credentials were not supplied. open data access only

# %%
events.columns
# Out:
# Index(['50_50', 'ball_receipt_outcome', 'ball_recovery_recovery_failure',
#        'block_deflection', 'carry_end_location', 'clearance_aerial_won',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_penalty', 'foul_committed_type', 'foul_won_advantage',
#        'foul_won_defensive', 'foul_won_penalty', 'goalkeeper_body_part',
#        'goalkeeper_end_location', 'goalkeeper_outcome', 'goalkeeper_position',
#        'goalkeeper_technique', 'goalkeeper_type', 'id', 'index',
#        'interception_outcome', 'location', 'match_id', 'minute',
#        'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id',
#        'pass_backheel', 'pass_body_part', 'pass_cross', 'pass_cut_back',
#        'pass_deflected', 'pass_end_location', 'pass_goal_assist',
# ...

# %%
events[events.shot_statsbomb_xg.isnull()==False]
# Out:
#      50_50 ball_receipt_outcome ball_recovery_recovery_failure  \
# 2992   NaN                  NaN                            NaN
# 2993   NaN                  NaN                            NaN
# 2994   NaN                  NaN                            NaN
# 2995   NaN                  NaN                            NaN
# 2996   NaN                  NaN                            NaN
# 2997   NaN                  NaN                            NaN
# 2998   NaN                  NaN                            NaN
# 2999   NaN                  NaN                            NaN
# 3000   NaN                  NaN                            NaN
# 3001   NaN                  NaN                            NaN
# 3002   NaN                  NaN                            NaN
# 3003   NaN                  NaN                            NaN
# 3004   NaN                  NaN                            NaN
# 3005   NaN                  NaN                            NaN
# ...

# %%
events.to_csv("Peru_WC18_Den.csv", index=None)

# %%
import pandas as pd

# %%
df1 = pd.read_csv("Peru_WC18_Den.csv")

# %%
df1.head()
# Out:
#   50_50 ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0   NaN                  NaN                            NaN              NaN
# 1   NaN                  NaN                            NaN              NaN
# 2   NaN                  NaN                            NaN              NaN
# 3   NaN                  NaN                            NaN              NaN
# 4   NaN                  NaN                            NaN              NaN
#
#   carry_end_location clearance_aerial_won counterpress dribble_nutmeg  \
# 0                NaN                  NaN          NaN            NaN
# 1                NaN                  NaN          NaN            NaN
# 2                NaN                  NaN          NaN            NaN
# 3                NaN                  NaN          NaN            NaN
# 4                NaN                  NaN          NaN            NaN
#
#   dribble_outcome dribble_overrun  ... shot_statsbomb_xg shot_technique  \
# ...

# %%
df1.groupby(by=["team"])[["shot_statsbomb_xg"]].sum()
# Out:
#          shot_statsbomb_xg
# team
# Denmark           0.924954
# Peru              1.830846
